# %%
import numpy as np

# %%
#a)
p = 10**34
q = 1.0
resultado = p+q-p
print(q)
# Out:
# 1.0

# %%
#b)
p = 100
q = 10**(-15)

resultado_1_1 = (p+q) + q
resultado_1_2 = p + 2*q

print(resultado_1_1)
print(resultado_1_2)


resultado_2_1 = ((p+q) + q) + q
resultado_2_2 = p + 3*q

print(resultado_2_1)
print(resultado_2_2)
# Out:
# 100.0
# 100.0
# 100.0
# 100.0
# 1e-15

# %%
eps = np. finfo ( float ). eps
print(eps)
# Out:
# 2.220446049250313e-16
