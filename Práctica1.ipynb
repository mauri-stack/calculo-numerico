# %%
import numpy as np
import matplotlib.pyplot as plt

eps = np.finfo(float).eps

# %%
#a)
p = 10.0**34
print(type(p))

p = 10**34
print(type(p))

q = 1.0
print(type(q))

resultado = p+q-p
print(q)
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# 1.0

# %%
#b)
p = 100.0
q = 10.0**(-15)

resultado_1_1 = (p+q) + q
resultado_1_2 = p + 2*q

print(resultado_1_1)
print(resultado_1_2)


resultado_2_1 = ((p+q) + q) + q
resultado_2_2 = p + 3*q

print(resultado_2_1)
print(resultado_2_2)
# Out:
# 100.0
# 100.0
# 100.0
# 100.0

# %%
#c y d

print(0.1+0.2)

print(0.1+0.3)
# Out:
# 0.30000000000000004
# 0.4

# %%
eps = np. finfo ( float ). eps
print(eps)

print(1 + eps)
print(1 + eps/2)
# Out:
# 2.220446049250313e-16
# 1.0000000000000002
# 1.0

# %%
#e

def f(x):
    y = (1 - np.cos(x)) / x**2
    return y



I = np.linspace(-4e-8, 4e-8, 10000)

plt.plot(I, f(I), ".k")
#plt.xlim(-1e-8, 1.1e-8)
plt.show()
# Out:
# 0.0

# %%
# f
print(eps)
print(eps/2)
# Out:
# 2.220446049250313e-16
# 1.1102230246251565e-16

# %%
#g
print((1 + eps/2) + eps/2)
# Out:
# 1.0

# %%
#h
print(1 + (eps/2 + eps/2))
# Out:
# 1.0000000000000002

# %%
#i
print(((1 + eps/2) + eps/2) - 1.0)
# Out:
# 0.0

# %%
#j
print(1+ (eps/2 + eps/2))

print((1+ (eps/2 + eps/2)) -1)

print(eps)

a = 1+ (eps/2 + eps/2)
print(a - 1)
# Out:
# 1.0000000000000002
# 2.220446049250313e-16
# 2.220446049250313e-16
# 2.220446049250313e-16

# %%
#k
for j in range(1,25 + 1):
    print(f'j = {j} ', np.sin(np.pi * 10**j))
# Out:
# j = 1  -1.2246467991473533e-15
# j = 2  1.964386723728472e-15
# j = 3  -3.2141664592756335e-13
# j = 4  -4.85682353956849e-13
# j = 5  -3.3960653996302193e-11
# j = 6  -2.2319121813608713e-10
# j = 7  5.620555424855643e-10
# j = 8  -3.9082928156687315e-08
# j = 9  -3.3201412914529495e-08
# j = 10  -2.2393627619559233e-06
# j = 11  -1.476423308779156e-05
# j = 12  -0.00026971264011324254
# j = 13  -0.0026971231637969895
# j = 14  -0.01134602089120528
# j = 15  -0.23620905325174094
# j = 16  -0.3752128900123343
# j = 17  -0.8479696810401983
# j = 18  -0.6416534819105046
# j = 19  0.7463367130158112
# j = 20  -0.39407096042476475
# j = 21  -0.5808054397535704
# j = 22  -0.6886746870200211
# j = 23  -0.7965162588457233
# j = 24  0.9301407542552305
# j = 25  0.9948086285918382

# %%
for j in range(1,25 + 1):
    print(f'j = {j} ', (10.0**j * np.pi))
# Out:
# j = 1  31.41592653589793
# j = 2  314.1592653589793
# j = 3  3141.592653589793
# j = 4  31415.926535897932
# j = 5  314159.2653589793
# j = 6  3141592.653589793
# j = 7  31415926.535897933
# j = 8  314159265.3589793
# j = 9  3141592653.589793
# j = 10  31415926535.89793
# j = 11  314159265358.9793
# j = 12  3141592653589.793
# j = 13  31415926535897.93
# j = 14  314159265358979.3
# j = 15  3141592653589793.0
# j = 16  3.1415926535897932e+16
# j = 17  3.141592653589793e+17
# j = 18  3.1415926535897933e+18
# j = 19  3.141592653589793e+19
# j = 20  3.1415926535897933e+20
# j = 21  3.141592653589793e+21
# j = 22  3.141592653589793e+22
# j = 23  3.1415926535897926e+23
# j = 24  3.141592653589793e+24
# j = 25  3.1415926535897935e+25

# %%
#l
for j in range(1,25 + 1):
    print(f'j = {j} ', np.sin(np.pi/2 + np.pi * 10**j))
# Out:
# j = 1  1.0
# j = 2  1.0
# j = 3  1.0
# j = 4  1.0
# j = 5  1.0
# j = 6  1.0
# j = 7  1.0
# j = 8  0.9999999999999984
# j = 9  0.9999999999999916
# j = 10  0.9999999999987206
# j = 11  0.9999999999468543
# j = 12  0.999999964819047
# j = 13  0.9999949407725442
# j = 14  0.9998070905094508
# j = 15  0.9525593659368664
# j = 16  -0.3752128900123343
# j = 17  -0.8479696810401983
# j = 18  -0.6416534819105046
# j = 19  0.7463367130158112
# j = 20  -0.39407096042476475
# j = 21  -0.5808054397535704
# j = 22  -0.6886746870200211
# j = 23  -0.7965162588457233
# j = 24  0.9301407542552305
# j = 25  0.9948086285918382

# %%
#veo si a partir de j = 15 la distribución es uniforme entre 0 y 1

muestras = []
for j in range(1,250 + 1):
    muestras.append(np.sin(np.pi/2 + np.pi * 10**j))
n = len(muestras)

fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.hist(muestras, density=True, bins = 10, histtype='barstacked', alpha=0.7, color='teal', edgecolor='gray')
#ax.hist(muestras, density=True, bins=np.arange(-0.5, n+1.5, 1), histtype='barstacked', alpha=0.7, color='darkmagenta', edgecolor='indigo')
ax.set_title('Datos Grupo A')
ax.set_xlabel('variable aleatoria', fontsize=13)
#label = ax.set_ylabel('Densidad de\nprobabilidad', rotation=0, labelpad=55, fontsize=13)
#label.set_position((-0.1, 0.38))  # (x, y) en coordenadas relativas del eje
#ax.set_ylabel('Densidad de \nprobabilidad', rotation=0, labelpad=40)
#ax.set_xlim(0, 11.5)
#ax.legend(title=f'$p_0$ = {p0_estimado:.4f} ± {sigma_p0:.4f}', loc='upper left', frameon=True)
plt.show()
